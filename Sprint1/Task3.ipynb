// %% [markdown]
// <h1 style="color:DodgerBlue">Индивидальный проект</h1>

// %% [markdown]
// <h2 style="color:DodgerBlue">Название проекта:</h2>
//
// ----
//
// ### Вариант задания № 1

// %% [markdown]
// <h2 style="color:DodgerBlue">Описание проекта:</h2>
//
// ----
//
// Описание задачи:
// Создать базовый класс Person в C#, который будет представлять информацию о
// человеке. На основе этого класса разработать 2-3 производных класса,
// демонстрирующих принципы наследования и полиморфизма. В каждом из классов
// должны быть реализованы новые атрибуты и методы, а также переопределены
// некоторые методы базового класса для демонстрации полиморфизма.
// Требования к базовому классу Person:
// • Атрибуты: Имя (Name), Возраст (Age), Пол (Gender).
// • Методы:
// o GetInfo(): метод для получения информации о человеке в виде строки.
// o SayHello(): метод для вывода приветствия от человека.
// Требования к производным классам:
// 1. Студент (Student): Должен содержать дополнительные атрибуты, такие как
// Университет (University) и Курс (Course). Метод SayHello() должен быть
// переопределен для добавления информации о курсе при приветствии.
// 2. Работник (Employee): Должен содержать дополнительные атрибуты, такие
// как Компания (Company) и Зарплата (Salary). Метод GetInfo() должен быть
// переопределен для включения информации о компании и зарплате.
// 3. Преподаватель (Teacher) (если требуется третий класс): Должен содержать
// дополнительные атрибуты, такие как Предмет (Subject) и Стаж работы
// (Experience). Метод SayHello() должен быть переопределен для добавления
// информации о преподаваемом предмете при приветствии.
//
// Дополнительное задание
//
// Добавьте к существующим классам конструктора классов с использованием геттеров и сеттеров и реализуйте взаимодействие
// объектов между собой

// %% [markdown]
// <h2 style="color:DodgerBlue">Реализация:</h2>
//
// ----

// %%
using System;

class Person
{
    // Свойства (геттеры и сеттеры)
    public string Name { get; set; }
    public int Age { get; set; }
    public string Gender { get; set; }

    // Конструктор базового класса
    public Person(string name, int age, string gender)
    {
        Name = name;
        Age = age;
        Gender = gender;
    }

    // Метод для получения информации о человеке
    public virtual string GetInfo()
    {
        return $"Имя: {Name}, Возраст: {Age}, Пол: {Gender}";
    }

    // Метод для приветствия
    public virtual void SayHello()
    {
        Console.WriteLine($"Привет! Меня зовут {Name}.");
    }
}

// Производный класс Student
class Student : Person
{
    public string University { get; set; }
    public int Course { get; set; }

    // Конструктор с использованием конструктора базового класса
    public Student(string name, int age, string gender, string university, int course)
        : base(name, age, gender)
    {
        University = university;
        Course = course;
    }

    // Переопределение метода SayHello для студента
    public override void SayHello()
    {
        Console.WriteLine($"Привет! Меня зовут {Name}, я учусь на {Course}-м курсе в {University}.");
    }

    // Переопределение метода GetInfo для студента
    public override string GetInfo()
    {
        return base.GetInfo() + $", Университет: {University}, Курс: {Course}";
    }
}

// Производный класс Employee
class Employee : Person
{
    public string Company { get; set; }
    public double Salary { get; set; }

    // Конструктор с использованием конструктора базового класса
    public Employee(string name, int age, string gender, string company, double salary)
        : base(name, age, gender)
    {
        Company = company;
        Salary = salary;
    }

    // Переопределение метода GetInfo для работника
    public override string GetInfo()
    {
        return base.GetInfo() + $", Компания: {Company}, Зарплата: {Salary:C}";
    }

    // Метод SayHello без изменений (использует метод базового класса)
}

// Производный класс Teacher
class Teacher : Person
{
    public string Subject { get; set; }
    public int Experience { get; set; }

    // Конструктор с использованием конструктора базового класса
    public Teacher(string name, int age, string gender, string subject, int experience)
        : base(name, age, gender)
    {
        Subject = subject;
        Experience = experience;
    }

    // Переопределение метода SayHello для преподавателя
    public override void SayHello()
    {
        Console.WriteLine($"Привет! Меня зовут {Name}, и я преподаю {Subject} уже {Experience} лет.");
    }

    // Переопределение метода GetInfo для преподавателя
    public override string GetInfo()
    {
        return base.GetInfo() + $", Предмет: {Subject}, Опыт: {Experience} лет";
    }
}



    
    
// Создание объектов
Student student = new Student("Алиса", 20, "Женский", "Гарвард", 2);
Employee employee = new Employee("Ольга", 35, "Женский", "Google", 75000);
Teacher teacher = new Teacher("Иван", 45, "Мужской", "Математика", 20);

// Демонстрация взаимодействия между объектами
teacher.SayHello();
student.SayHello();

Console.WriteLine("\nИнформация о людях:");
Console.WriteLine(student.GetInfo());
Console.WriteLine(employee.GetInfo());
Console.WriteLine(teacher.GetInfo());

Console.WriteLine("\nПример взаимодействия объектов:");
// Пример взаимодействия: преподаватель спрашивает студента о его учебе
Console.WriteLine($"{teacher.Name}: Привет, {student.Name}! На каком курсе ты учишься?");
Console.WriteLine($"{student.Name}: Я учусь на {student.Course}-м курсе в {student.University}.");

// Работник разговаривает с преподавателем о работе
Console.WriteLine($"{employee.Name}: Здравствуйте, {teacher.Name}! Вы преподаватель {teacher.Subject}. А я работаю в {employee.Company}.");
Console.WriteLine($"{teacher.Name}: Рад встрече, {employee.Name}. Как у вас с работой?");
// Out:
// Привет! Меня зовут Иван, и я преподаю Математика уже 20 лет.
// Привет! Меня зовут Алиса, я учусь на 2-м курсе в Гарвард.
//
// Информация о людях:
// Имя: Алиса, Возраст: 20, Пол: Женский, Университет: Гарвард, Курс: 2
// Имя: Ольга, Возраст: 35, Пол: Женский, Компания: Google, Зарплата: ¤75,000.00
// Имя: Иван, Возраст: 45, Пол: Мужской, Предмет: Математика, Опыт: 20 лет
//
// Пример взаимодействия объектов:
// Иван: Привет, Алиса! На каком курсе ты учишься?
// Алиса: Я учусь на 2-м курсе в Гарвард.
// Ольга: Здравствуйте, Иван! Вы преподаватель Математика. А я работаю в Google.
// Иван: Рад встрече, Ольга. Как у вас с работой?
